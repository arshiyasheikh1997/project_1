# %%
import pandas as pd

# %%
import openpyxl

# %%
df=pd.read_csv("C:\\Users\\user\\OneDrive\\Documents\\spotify_data clean.csv")

# %%
df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.isna()
# Out:
#       track_id  track_name  track_number  track_popularity  explicit  \
# 0        False       False         False             False     False
# 1        False       False         False             False     False
# 2        False       False         False             False     False
# 3        False       False         False             False     False
# 4        False       False         False             False     False
# ...        ...         ...           ...               ...       ...
# 8577     False       False         False             False     False
# 8578     False       False         False             False     False
# 8579     False       False         False             False     False
# 8580     False       False         False             False     False
# 8581     False       False         False             False     False
#
#       artist_name  artist_popularity  artist_followers  artist_genres  \
# ...

# %%
df.dropna()
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5     4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
new_df=df.dropna()

# %%
new_df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5     4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %% [markdown]
#  conact merge and join

# %%
data1={'id':[101,102,103,104,105],'name':['gita','hina','jayashre','kiran','kunal'],'add':['pune','agra','hingna','gondiya','delhi'],'mo_no':[97,89,78,85,88]}

# %%
df=pd.DataFrame(data1)

# %%
df
# Out:
#     id      name      add  mo_no
# 0  101      gita     pune     97
# 1  102      hina     agra     89
# 2  103  jayashre   hingna     78
# 3  104     kiran  gondiya     85
# 4  105     kunal    delhi     88

# %%
data2={'id':[1,2,3,4,5],'name':['nita','jitu','balu','lina','vishal'],'add':['nagpur','raipur','amrawati','kolkata','dhule'],'qualification':['BA','BE','BCA','MCA','MSC']}

# %%
df1=pd.DataFrame(data2)

# %%
df1
# Out:
#    id    name       add qualification
# 0   1    nita    nagpur            BA
# 1   2    jitu    raipur            BE
# 2   3    balu  amrawati           BCA
# 3   4    lina   kolkata           MCA
# 4   5  vishal     dhule           MSC

# %%
df=pd.DataFrame(data1,index[0,1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=pd.DataFrame(data1,index[0,1,2,3,4])
#
# NameError: name 'index' is not defined

# %%
df1=pd.DataFrame(data2,index[4,5,6,7,8])
print(df,"n\n",df1)
